# %% [markdown]
# $$ K~ (x, x') = f(x) k(x,x') f(x') $$
#
# $$ K (x, x') = \phi(x) \cdot \phi(x') $$
#
# $$ K~ (x, x') = \varphi(x) \cdot \varphi(x') $$

# %% [markdown]
# $$ K(x, x') = \exp(- \frac{1}{2} ||x-x'||^2) $$
#
# $$ K(x,x') = e^{(- \frac{1}{2} ||x-x'||^2)} $$
